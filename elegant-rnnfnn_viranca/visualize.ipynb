# %%
from visualization import plot_util as pu

# %% [markdown]
# If you want to average results for multiple seeds, LOG_DIRS must contain subfolders in the following format: ```<name_exp0>-0```, ```<name_exp0>-1```, ```<name_exp1>-0```, ```<name_exp1>-1```. Where names correspond to experiments you want to compare separated with random seeds by dash.

# %%
# LOG_DIRS = 'logs/halfcheetah'
# Uncomment below to see the effect of the timit limits flag
# LOG_DIRS = 'time_limit_logs/reacher'
# LOG_DIRS = 'ware/fnn/results/1' # FNN result Taylan
# LOG_DIRS = 'ware/rnn/results/1' # RNN result Taylan
# LOG_DIRS = 'ware/IAM/results/1' # IAM result Taylan
# LOG_DIRS = 'ware/IAM-M/results/1' # IAM-M result Taylan
# LOG_DIRS = 'ware/fnn/results/vir2' # Result Taylan

# %%
results = pu.load_results(LOG_DIRS)
# Out:
# C:\Users\Kevin Bislip\Desktop\DL\DL PPO2\CS4240_Deep_Learning_Project\elegant-rnnfnn_viranca\visualization\monitor.py:162: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '',
                      shaded_std=True, xlabel='Update steps', ylabel='Results')
